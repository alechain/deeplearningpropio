# %% [markdown]
# # Simulación del problema de Monty Hall

# %%
import numpy as np
cambiar=0
no_cambiar=0
aleatorio=0

cambiar_acumulado=[]
no_cambiar_acumulado=[]
aleatorio_acumulado=[]

n=1000

# %%
for i in range (n):
        puertas=[1,2,3]
        auto= np.random.randint(1,4)
        eleccion= np.random.randint(1,4)
        puertas.remove(eleccion)

        if eleccion == auto:
            no_cambiar=no_cambiar + 1
            puertasdisp=puertas[np.random.randint(2)]
        else:
            puertas.remove(auto)
            puertasdisp = puertas[0]
            cambiar= cambiar+1
            
        cambiar_acumulado.append(cambiar)
        no_cambiar_acumulado.append(no_cambiar)

# %%
     
for i in range(n):
        puertas_ale=[1,2,3]
        auto_ale=np.random.randint(1,4)
        eleccion_ale=np.random.randint(1,4)
        puertas_ale.remove(eleccion_ale)
        puertas_ale.remove(auto_ale)
        puertas_por

        if np.random.randint(2)==1 &  eleccion_ale==auto_ale:
            aleatorio += 1
        elif puertas_ale==auto_ale:
            aleatorio+=1
        aleatorio_acumulado.append(aleatorio)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-31231a13843a> in <module>
#       3         auto_ale=np.random.randint(1,4)
#       4         eleccion_ale=np.random.randint(1,4)
# ----> 5         puertas_ale.remove(eleccion_ale,auto_ale)
#       6
#       7         if np.random.randint(2)==1 &  eleccion_ale==auto_ale:
#
# TypeError: remove() takes exactly one argument (2 given)

# %%
from matplotlib import pyplot as plt


plt.figure(figsize=(20,10))
plt.plot(cambiar_acumulado, label="cambiar", color="#32a8a8", linestyle="--")
plt.plot(no_cambiar_acumulado, label="No cambiar", color="#d90f0f", linestyle="--")
plt.plot(aleatorio_acumulado)
plt.text(x=1000, y=cambiar, s=cambiar, size=15)
plt.text(x=1000, y=no_cambiar, s=no_cambiar, size=15)
plt.xlabel("Intentos")
plt.ylabel("Aciertos")
plt.legend()

# %%
# Out:
# 1
